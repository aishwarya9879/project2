# %%
import numpy as np
import scipy.stats as stats
import pandas as pd


# this line tells jupyter notebook to put the plots in the notebook rather than saving them to file.
# %matplotlib inline

# this line makes plots prettier on mac retina screens. If you don't have one it shouldn't do anything.
# %config InlineBackend.figure_format = 'retina'

# %%
# check the iowa file location for your computer 
iowa_file = 'Iowa_Liquor_sales_sample_10pct.csv'

iowa = pd.read_csv(iowa_file)
print "Dataframe is of size: " + str(iowa.values.nbytes / 10**6) + "MB"
# Out:
# Dataframe is of size: 39MB

# %%
iowa.describe()
# Out:
# /Users/aishwaryachinnari/anaconda/envs/dsi/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#         Store Number  County Number      Category  Vendor Number  \
# count  270955.000000  269878.000000  2.708870e+05   270955.00000
# mean     3590.263701      57.231642  1.043888e+06      256.43443
# std       947.662050      27.341205  5.018211e+04      141.01489
# min      2106.000000       1.000000  1.011100e+06       10.00000
# 25%      2604.000000            NaN           NaN      115.00000
# 50%      3722.000000            NaN           NaN      260.00000
# 75%      4378.000000            NaN           NaN      380.00000
# max      9023.000000      99.000000  1.701100e+06      978.00000
#
#          Item Number  Bottle Volume (ml)   Bottles Sold  Volume Sold (Liters)  \
# count  270955.000000       270955.000000  270955.000000         270955.000000
# ...

# %%
iowa.columns
# Out:
# Index([u'Date', u'Store Number', u'City', u'Zip Code', u'County Number',
#        u'County', u'Category', u'Category Name', u'Vendor Number',
#        u'Item Number', u'Item Description', u'Bottle Volume (ml)',
#        u'State Bottle Cost', u'State Bottle Retail', u'Bottles Sold',
#        u'Sale (Dollars)', u'Volume Sold (Liters)', u'Volume Sold (Gallons)'],
#       dtype='object')

# %%
iowa.isnull().sum()

#iowa.isnull().values.any()
# Out:
# Date                        0
# Store Number                0
# City                        0
# Zip Code                    0
# County Number            1077
# County                   1077
# Category                   68
# Category Name             632
# Vendor Number               0
# Item Number                 0
# Item Description            0
# Bottle Volume (ml)          0
# State Bottle Cost           0
# State Bottle Retail         0
# Bottles Sold                0
# Sale (Dollars)              0
# Volume Sold (Liters)        0
# Volume Sold (Gallons)       0
# dtype: int64

# %%
iowa = iowa[iowa['County Number'] > 0 ]
iowa = iowa[iowa['County'] > 0 ]
iowa = iowa[iowa['Category'] > 0 ]
iowa = iowa[iowa['Category Name'] > 0 ]
iowa.isnull().sum()

#iowa.drop_duplicates(inplace=True)
# Out:
# Date                     0
# Store Number             0
# City                     0
# Zip Code                 0
# County Number            0
# County                   0
# Category                 0
# Category Name            0
# Vendor Number            0
# Item Number              0
# Item Description         0
# Bottle Volume (ml)       0
# State Bottle Cost        0
# State Bottle Retail      0
# Bottles Sold             0
# Sale (Dollars)           0
# Volume Sold (Liters)     0
# Volume Sold (Gallons)    0
# Year                     0
# dtype: int64

# %%
iowa.head()
# Out:
#         Date  Store Number         City Zip Code  County Number      County  \
# 0 2015-11-04          3717       SUMNER    50674            9.0      Bremer
# 1 2016-03-02          2614    DAVENPORT    52807           82.0       Scott
# 2 2016-02-11          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3 2016-02-03          2501         AMES    50010           85.0       Story
# 4 2015-08-18          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# ...

# %%
iowa.Date = pd.to_datetime(iowa.Date)
iowa.head()
#print iowa['Date'].datetime.now()
# Out:
#         Date  Store Number         City Zip Code  County Number      County  \
# 0 2015-11-04          3717       SUMNER    50674            9.0      Bremer
# 1 2016-03-02          2614    DAVENPORT    52807           82.0       Scott
# 2 2016-02-11          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3 2016-02-03          2501         AMES    50010           85.0       Story
# 4 2015-08-18          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# ...

# %%
#msk = (iowa['Date'].year >= 2015) & (iowa['Date'].year < 2016)
#iowa['Date'].mask(msk)
dates = pd.DatetimeIndex(iowa['Date'])

iowa['Year']=dates.year
iowa

#numpy.timedelta64(366,'D')

#iowa[iowa[dtype.Date('O' == 2015)]]
# Out:
#              Date  Store Number             City Zip Code  County Number  \
# 0      2015-11-04          3717           SUMNER    50674            9.0
# 1      2016-03-02          2614        DAVENPORT    52807           82.0
# 2      2016-02-11          2106      CEDAR FALLS    50613            7.0
# 3      2016-02-03          2501             AMES    50010           85.0
# 4      2015-08-18          3654          BELMOND    50421           99.0
# 5      2015-04-20          2569     CEDAR RAPIDS    52402           57.0
# 6      2015-08-05          2596          OTTUMWA    52501           90.0
# 7      2015-06-25          3456       CLEAR LAKE    50428           17.0
# 8      2016-01-04          4757        BONDURANT    50035           77.0
# 9      2015-11-10          4346       SHELLSBURG    52332            6.0
# 10     2015-09-28          2648  WEST DES MOINES    50265           77.0
# 11     2015-10-28          2600        OSKALOOSA    52577           62.0
# ...

# %%
iowa_subset = iowa.loc[:,['Store Number','Year','Sale (Dollars)','Date']]
iowa_subset
# Out:
#             Store Number  Year Sale (Dollars)       Date
# Date
# 2015-11-04          3717  2015         $81.00 2015-11-04
# 2016-03-02          2614  2016         $41.26 2016-03-02
# 2016-02-11          2106  2016        $453.36 2016-02-11
# 2016-02-03          2501  2016         $85.50 2016-02-03
# 2015-08-18          3654  2015        $129.60 2015-08-18
# 2015-04-20          2569  2015        $119.88 2015-04-20
# 2015-08-05          2596  2015         $29.97 2015-08-05
# 2015-06-25          3456  2015         $47.26 2015-06-25
# 2016-01-04          4757  2016         $68.96 2016-01-04
# 2015-11-10          4346  2015         $22.86 2015-11-10
# 2015-09-28          2648  2015        $236.16 2015-09-28
# 2015-10-28          2600  2015         $55.50 2015-10-28
# 2015-01-22          3858  2015         $13.38 2015-01-22
# 2016-02-29          4673  2016        $180.00 2016-02-29
# 2016-01-04          2670  2016        $135.00 2016-01-04
# ...

# %%
l = pd.to_datetime('20150101', format='%Y%m%d')
r = pd.to_datetime('20160101', format='%Y%m%d')
rng = pd.date_range(l,r)
rng
#mask = (iowa['Date'] > l) & (iowa['Date'] < r)

#iowa['Date']
#iowa = iowa.irow[mask]
#print iowa
#3iowa.loc[:,(iowa['Date'] > l) & (iowa['Date'] < r)]
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10',
#                ...
#                '2015-12-23', '2015-12-24', '2015-12-25', '2015-12-26',
#                '2015-12-27', '2015-12-28', '2015-12-29', '2015-12-30',
#                '2015-12-31', '2016-01-01'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
iowa_subset.index= iowa_subset['Date']
iowa_subset.loc[rng]
# Out:
#             Store Number    Year Sale (Dollars)       Date
# Date
# 2015-01-01           NaN     NaN            NaN        NaT
# 2015-01-02           NaN     NaN            NaN        NaT
# 2015-01-03           NaN     NaN            NaN        NaT
# 2015-01-04           NaN     NaN            NaN        NaT
# 2015-01-05        3562.0  2015.0        $117.00 2015-01-05
# 2015-01-05        2643.0  2015.0         $39.36 2015-01-05
# 2015-01-05        4752.0  2015.0         $90.00 2015-01-05
# 2015-01-05        2584.0  2015.0         $70.56 2015-01-05
# 2015-01-05        4572.0  2015.0         $17.99 2015-01-05
# 2015-01-05        2613.0  2015.0         $23.58 2015-01-05
# 2015-01-05        2538.0  2015.0         $59.76 2015-01-05
# 2015-01-05        2528.0  2015.0        $206.88 2015-01-05
# 2015-01-05        2506.0  2015.0         $61.90 2015-01-05
# 2015-01-05        4180.0  2015.0         $72.00 2015-01-05
# 2015-01-05        4421.0  2015.0        $121.50 2015-01-05
# ...

# %%
#iowa.isnull().sum()
iowa_by_store = iowa_subset.groupby('Store Number')

# %%
# Clean up missing values in multiple DataFrame columns
#df = iowa.fillna({
#    'col1': 'missing',
#    'col2': '99.999',
#    'col3': '999',
#    'col4': 'missing',
#    'col5': 'missing',
#    'col6': '99'
#})
# Out:
# 269258

# %%
# Out:
# 269258

# %%
# Out:
#              Date  Store Number             City Zip Code  County Number  \
# 270950 2015-12-22          4057       DES MOINES    50316           77.0
# 270951 2015-11-04          5151        IDA GROVE    51445           47.0
# 270952 2015-10-20          5152         WATERLOO    50702            7.0
# 270953 2015-11-20          3562  WEST BURLINGTON    52655           29.0
# 270954 2015-01-27          4446        URBANDALE    50322           77.0
#
#             County   Category                       Category Name  \
# 270950        Polk  1022100.0                             TEQUILA
# 270951         Ida  1011200.0           STRAIGHT BOURBON WHISKIES
# 270952  Black Hawk  1011300.0                  TENNESSEE WHISKIES
# 270953  Des Moines  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 270954        Polk  1031080.0                      VODKA 80 PROOF
#
#         Vendor Number  Item Number               Item Description  \
# ...
